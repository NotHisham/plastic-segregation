# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train YOLOv8 Object Detection on a Custom Dataset
#
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset)
# [![YouTube](https://badges.aleen42.com/src/youtube.svg)](https://youtu.be/wuZtUMEiKWY)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/ultralytics/ultralytics)
#
# Ultralytics YOLOv8 is a popular version of the YOLO (You Only Look Once) object detection and image segmentation model developed by Ultralytics. The YOLOv8 model is designed to be fast, accurate, and easy to use, making it an excellent choice for a wide range of object detection and image segmentation tasks. It can be trained on large datasets and is capable of running on a variety of hardware platforms, from CPUs to GPUs.
#
# ## Disclaimer
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# ## Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the accompanying [Blog Post](https://blog.roboflow.com/how-to-train-yolov8-on-a-custom-dataset/).
#
# ## Pro Tip: Use GPU Acceleration
#
# If you are running this notebook in Google Colab, navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`. This will ensure your notebook uses a GPU, which will significantly speed up model training times.
#
# ## Steps in this Tutorial
#
# In this tutorial, we are going to cover:
#
# - Before you start
# - Install YOLOv8
# - CLI Basics
# - Inference with Pre-trained COCO Model
# - Roboflow Universe
# - Preparing a custom dataset
# - Custom Training
# - Validate Custom Model
# - Inference with Custom Model
#
# **Let's begin!**

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sun Sep 14 08:21:40 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   53C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/{HOME}/datasets/{HOME}/datasets

# %% [markdown]
# ## Install YOLOv8
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

# prevent ultralytics from tracking your activity
# !yolo settings sync=False

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.9/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://docs.ultralytics.com/usage/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content/{HOME}/datasets/{HOME}/datasets
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.25M/6.25M [00:00<00:00, 116MB/s]
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to 'dog.jpeg'...
# 100% 104k/104k [00:00<00:00, 107MB/s]
# image 1/1 /content/{HOME}/datasets/{HOME}/datasets/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 41.8ms
# Speed: 2.5ms preprocess, 41.8ms inference, 293.2ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/dog.jpeg', height=600)
# Out:
# /content/{HOME}/datasets/{HOME}/datasets

# %% [markdown]
# ### 🐍 Python SDK
#
# The simplest way of simply using YOLOv8 directly in a Python environment.

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-392492458.py in <cell line: 0>()
#       1 model = YOLO(f'{HOME}/yolov8n.pt')
# ----> 2 results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     553         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     554             self.predictor.set_prompts(prompts)
# --> 555         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     556
#     557     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     166             return self.stream_inference(source, model, *args, **kwargs)
#     167         else:
# --> 168             return list(self.stream_inference(source, model, *args, **kwargs))  # merge list of Result into one
#     169
#     170     def predict_cli(self, source=None, model=None):
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in generator_context(*args, **kwargs)
#      36             # Issuing `None` to a generator fires it up
#      37             with ctx_factory():
# ---> 38                 response = gen.send(None)
#      39
#      40             while True:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in stream_inference(self, source, model, *args, **kwargs)
#     232             # Warmup model
#     233             if not self.done_warmup:
# --> 234                 self.model.warmup(imgsz=(1 if self.model.pt or self.model.triton else self.dataset.bs, 3, *self.imgsz))
#     235                 self.done_warmup = True
#     236
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/autobackend.py in warmup(self, imgsz)
#     631             imgsz (tuple): The shape of the dummy input tensor in the format (batch_size, channels, height, width)
#     632         """
# --> 633         import torchvision  # noqa (import here so torchvision import time not recorded in postprocess time)
#     634
#     635         warmup_types = self.pt, self.jit, self.onnx, self.engine, self.saved_model, self.pb, self.triton, self.nn_module
#
# /usr/local/lib/python3.12/dist-packages/torchvision/__init__.py in <module>
#       8 # .extensions) before entering _meta_registrations.
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      11
#      12 try:
#
# /usr/local/lib/python3.12/dist-packages/torchvision/models/__init__.py in <module>
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#       5 from .googlenet import *
#
# /usr/local/lib/python3.12/dist-packages/torchvision/models/convnext.py in <module>
#       7 from torch.nn import functional as F
#       8
# ----> 9 from ..ops.misc import Conv2dNormActivation, Permute
#      10 from ..ops.stochastic_depth import StochasticDepth
#      11 from ..transforms._presets import ImageClassification
#
# /usr/local/lib/python3.12/dist-packages/torchvision/ops/__init__.py in <module>
#      21 from .giou_loss import generalized_box_iou_loss
#      22 from .misc import Conv2dNormActivation, Conv3dNormActivation, FrozenBatchNorm2d, MLP, Permute, SqueezeExcitation
# ---> 23 from .poolers import MultiScaleRoIAlign
#      24 from .ps_roi_align import ps_roi_align, PSRoIAlign
#      25 from .ps_roi_pool import ps_roi_pool, PSRoIPool
#
# /usr/local/lib/python3.12/dist-packages/torchvision/ops/poolers.py in <module>
#       8
#       9 from ..utils import _log_api_usage_once
# ---> 10 from .roi_align import roi_align
#      11
#      12
#
# /usr/local/lib/python3.12/dist-packages/torchvision/ops/roi_align.py in <module>
#       5 import torch.fx
#       6 from torch import nn, Tensor
# ----> 7 from torch._dynamo.utils import is_compile_supported
#       8 from torch.jit.annotations import BroadcastingList2
#       9 from torch.nn.modules.utils import _pair
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/__init__.py in <module>
#      11 import torch
#      12
# ---> 13 from . import config, convert_frame, eval_frame, resume_execution
#      14 from .backends.registry import list_backends, lookup_backend, register_backend
#      15 from .callback import callback_handler, on_compile_end, on_compile_start
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/convert_frame.py in <module>
#      51 from torch._dynamo.callback import CallbackTrigger
#      52 from torch._dynamo.distributed import get_compile_pg
# ---> 53 from torch._dynamo.symbolic_convert import TensorifyState
#      54 from torch._guards import compile_context, CompileContext, CompileId, tracing
#      55 from torch._logging import structured
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/symbolic_convert.py in <module>
#      50 import torch
#      51 import torch._logging
# ---> 52 from torch._dynamo.exc import TensorifyScalarRestartAnalysis
#      53 from torch._guards import tracing, TracingContext
#      54 from torch._logging.structured import dump_file
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/exc.py in <module>
#      39
#      40 from . import config
# ---> 41 from .utils import counters
#      42
#      43
#
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/utils.py in <module>
#     126             np.fft,
#     127             np.linalg,
# --> 128             np.random,
#     129         )
#     130
#
# /usr/local/lib/python3.12/dist-packages/numpy/__init__.py in __getattr__(attr)
#     335
#     336     def __dir__():
# --> 337         public_symbols = globals().keys() | {'testing'}
#     338         public_symbols -= {
#     339             "core", "matrixlib",
#
# /usr/local/lib/python3.12/dist-packages/numpy/random/__init__.py in <module>
#     178
#     179 # add these for module-freeze analysis (like PyInstaller)
# --> 180 from . import _pickle
#     181 from . import _common
#     182 from . import _bounded_integers
#
# /usr/local/lib/python3.12/dist-packages/numpy/random/_pickle.py in <module>
# ----> 1 from .mtrand import RandomState
#       2 from ._philox import Philox
#       3 from ._pcg64 import PCG64, PCG64DXSM
#       4 from ._sfc64 import SFC64
#       5
#
# numpy/random/mtrand.pyx in init numpy.random.mtrand()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject

# %%
results[0].boxes.xyxy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2151685523.py in <cell line: 0>()
# ----> 1 results[0].boxes.xyxy
#
# NameError: name 'results' is not defined

# %%
results[0].boxes.conf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2359826918.py in <cell line: 0>()
# ----> 1 results[0].boxes.conf
#
# NameError: name 'results' is not defined

# %%
results[0].boxes.cls
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-252594811.py in <cell line: 0>()
# ----> 1 results[0].boxes.cls
#
# NameError: name 'results' is not defined

# %% [markdown]
# ## Roboflow Universe
#
# Need data for your project? Before spending time on annotating, check out Roboflow Universe, a repository of more than 110,000 open-source datasets that you can use in your projects. You'll find datasets containing everything from annotated cracks in concrete to plant images with disease annotations.
#
#
# [![Roboflow Universe](https://media.roboflow.com/notebooks/template/uni-banner-frame.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672878480290)](https://universe.roboflow.com/)

# %% [markdown]
# ## Preparing a custom dataset
#
# Building a custom dataset can be a painful process. It might take dozens or even hundreds of hours to collect images, label them, and export them in the proper format. Fortunately, Roboflow makes this process as straightforward and fast as possible. Let me show you how!
#
# ### Step 1: Creating project
#
# Before you start, you need to create a Roboflow [account](https://app.roboflow.com/login). Once you do that, you can create a new project in the Roboflow [dashboard](https://app.roboflow.com/). Keep in mind to choose the right project type. In our case, Object Detection.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/creating-project.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929799852"
#   >
# </div>
#
# ### Step 2: Uploading images
#
# Next, add the data to your newly created project. You can do it via API or through our [web interface](https://docs.roboflow.com/adding-data/object-detection).
#
# If you drag and drop a directory with a dataset in a [supported format](https://roboflow.com/formats), the Roboflow dashboard will automatically read the images and annotations together.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/uploading-images.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672929808290"
#   >
# </div>
#
# ### Step 3: Labeling
#
# If you only have images, you can label them in [Roboflow Annotate](https://docs.roboflow.com/annotate).
#
# <div align="center">
#   <img
#     width="640"
#     src="https://user-images.githubusercontent.com/26109316/210901980-04861efd-dfc0-4a01-9373-13a36b5e1df4.gif"
#   >
# </div>
#
# ### Step 4: Generate new dataset version
#
# Now that we have our images and annotations added, we can Generate a Dataset Version. When Generating a Version, you may elect to add preprocessing and augmentations. This step is completely optional, however, it can allow you to significantly improve the robustness of your model.
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/generate-new-version.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1673003597834"
#   >
# </div>
#
# ### Step 5: Exporting dataset
#
# Once the dataset version is generated, we have a hosted dataset we can load directly into our notebook for easy training. Click `Export` and select the `YOLO v8` dataset format. (Formerly, we used to use `Yolov5`, as the gif shows)
#
# <div align="center">
#   <img
#     width="640"
#     src="https://media.roboflow.com/preparing-custom-dataset-example/export.gif?ik-sdk-version=javascript-1.4.3&updatedAt=1672943313709"
#   >
# </div>

# %% [markdown]
# 🟢 Tip: The examples below work even if you use our non-custom model. However, you won't be able to deploy it to Roboflow. To do that, create a custom dataset as described below or fork (copy) one into your workspace from Universe.

# %%
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow==1.1.48 --quiet
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="") #obtain this from roboflow.
project = rf.workspace("plasticsegregation").project("my-first-project-pmspv")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# /content/{HOME}/datasets/{HOME}/datasets/datasets
# Requirement already satisfied: roboflow in /usr/local/lib/python3.12/dist-packages (1.1.48)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from roboflow) (2025.8.3)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.12/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.4.9)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from roboflow) (11.3.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.32.4)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.12/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.12/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (4.59.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->roboflow) (3.4.3)
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in My-First-Project-1 to yolov8:: 100%|██████████| 210317/210317 [00:02<00:00, 73727.07it/s]
# Extracting Dataset Version Zip to My-First-Project-1 in yolov8:: 100%|██████████| 5452/5452 [00:04<00:00, 1343.07it/s]

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=50 imgsz=800 plots=True
# Out:
# /content/{HOME}/datasets/{HOME}/datasets
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt to 'yolov8s.pt'...
# 100% 21.5M/21.5M [00:00<00:00, 113MB/s]
# New https://pypi.org/project/ultralytics/8.3.199 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/data.yaml, epochs=50, time=None, patience=100, batch=16, imgsz=800, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 18.6MB/s]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757838219.711583    1971 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757838219.721834    1971 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1757838219.743953    1971 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757838219.744003    1971 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757838219.744011    1971 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1757838219.744018    1971 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Overriding model.yaml nc=80 with nc=8
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2119144  ultralytics.nn.modules.head.Detect           [8, [128, 256, 512]]
# Model summary: 225 layers, 11,138,696 parameters, 11,138,680 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/train/labels... 2505 images, 3 backgrounds, 0 corrupt: 100% 2505/2505 [00:01<00:00, 2169.30it/s]
# train: New cache created: /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/train/labels.cache
# /usr/local/lib/python3.12/dist-packages/ultralytics/data/augment.py:1837: UserWarning: Argument(s) 'quality_lower' are not valid for transform ImageCompression
#   A.ImageCompression(quality_lower=75, p=0.0),
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/valid/labels... 140 images, 0 backgrounds, 0 corrupt: 100% 140/140 [00:00<00:00, 890.20it/s]
# val: New cache created: /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000833, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      6.12G      1.493      2.064      1.563        194        800: 100% 157/157 [01:22<00:00,  1.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:03<00:00,  1
00:00,  2.21it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:01<00:00,  2.80it/s]
#                    all        140       1984      0.917      0.921      0.944      0.738
#
# 50 epochs completed in 1.058 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.6MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.6MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,128,680 parameters, 0 gradients, 28.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:04<00:00,  1.00it/s]
#                    all        140       1984      0.918       0.92      0.945       0.74
#               Color LD         91        164      0.915      0.945      0.959      0.768
#                     HM        132        485      0.927      0.944      0.957      0.765
#                    LD1         47         48      0.934      0.958       0.94        0.8
#                    LD2        135        337      0.892      0.883      0.929      0.708
#                    MLP        107        360      0.925      0.928       0.95      0.654
#           Milk Packets        124        239      0.971      0.966      0.988      0.704
#                     PP        129        314      0.866      0.846      0.878      0.675
#                 Raffia         33         37      0.915      0.892      0.955      0.842
# Speed: 0.4ms preprocess, 6.5ms inference, 0.0ms loss, 5.1ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content/{HOME}/datasets/{HOME}/datasets

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content/{HOME}/datasets/{HOME}/datasets

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content/{HOME}/datasets/{HOME}/datasets

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content/{HOME}/datasets/{HOME}/datasets
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,128,680 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/valid/labels.cache... 140 images, 0 backgrounds, 0 corrupt: 100% 140/140 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 9/9 [00:05<00:00,  1.74it/s]
#                    all        140       1984      0.918      0.915      0.945      0.739
#               Color LD         91        164      0.917       0.94      0.959      0.768
#                     HM        132        485      0.927      0.943      0.957      0.765
#                    LD1         47         48      0.936      0.958       0.94        0.8
#                    LD2        135        337      0.891      0.877      0.929      0.707
#                    MLP        107        360      0.925      0.926       0.95      0.654
#           Milk Packets        124        239      0.971      0.966      0.988      0.702
#                     PP        129        314      0.866      0.844      0.878      0.674
#                 Raffia         33         37      0.915      0.869      0.955      0.842
# Speed: 4.2ms preprocess, 13.8ms inference, 0.0ms loss, 2.6ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content/{HOME}/datasets/{HOME}/datasets
# Ultralytics YOLOv8.2.103 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,128,680 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_141856_jpg.rf.f7b8d7b736e40adeee0019a0ac4c36ac.jpg: 800x800 6 HMs, 3 LD2s, 3 Milk Packetss, 1 PP, 21.8ms
# image 2/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_141949_jpg.rf.6864eed7247e6118c85b35698e007e0b.jpg: 800x800 6 HMs, 2 LD2s, 3 Milk Packetss, 1 PP, 21.9ms
# image 3/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_141952_jpg.rf.44f4acf905f74db4904741097329c041.jpg: 800x800 6 HMs, 2 LD2s, 3 Milk Packetss, 1 PP, 21.8ms
# image 4/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_143335_jpg.rf.ec43b13a6beeae74e4bd676c2fad00f8.jpg: 800x800 1 Color LD, 1 HM, 1 LD1, 2 LD2s, 1 Milk Packets, 1 PP, 21.8ms
# image 5/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_143931_jpg.rf.37a60285ec6047e37301e7740f6a9e48.jpg: 800x800 2 Color LDs, 8 HMs, 1 LD1, 1 LD2, 1 Milk Packets, 21.8ms
# image 6/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_144223_jpg.rf.f0a0da6063d6d5a731541aaa4018a4e0.jpg: 800x800 1 Color LD, 7 HMs, 1 LD1, 4 LD2s, 3 Milk Packetss, 1 PP, 21.8ms
# image 7/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_144821_jpg.rf.fd3cf77b816250212cbc11bf7697a9f9.jpg: 800x800 1 Color LD, 5 HMs, 1 LD1, 3 LD2s, 2 Milk Packetss, 1 PP, 16.5ms
# image 8/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_145344_jpg.rf.08ea03adca0b69645d7f78077168d6b9.jpg: 800x800 2 Color LDs, 5 HMs, 1 LD1, 3 LD2s, 2 Milk Packetss, 3 PPs, 16.6ms
# image 9/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_150046_jpg.rf.ea067196194ada499d9025194fbac635.jpg: 800x800 4 HMs, 2 LD2s, 2 Milk Packetss, 2 PPs, 16.5ms
# image 10/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_151441_jpg.rf.b0ec19c0dcc590f1ccda02582044bcf0.jpg: 800x800 1 Color LD, 4 HMs, 6 LD2s, 2 MLPs, 1 Milk Packets, 1 PP, 16.5ms
# image 11/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_151717_jpg.rf.a717662993a32fdbc350ec68a1380970.jpg: 800x800 1 Color LD, 3 HMs, 6 LD2s, 1 MLP, 1 Milk Packets, 2 PPs, 16.4ms
# image 12/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_152345_jpg.rf.992ffc59e74b8e0f7a8570a0228eac5b.jpg: 800x800 5 HMs, 5 LD2s, 1 MLP, 1 Milk Packets, 3 PPs, 16.3ms
# image 13/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_152916_jpg.rf.8c00519c83a8bf5d8249da6dff49073e.jpg: 800x800 1 Color LD, 3 HMs, 7 LD2s, 4 MLPs, 1 Milk Packets, 2 PPs, 16.3ms
# image 14/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_152917_jpg.rf.dc7dd3ff173b7b2572af8e41ddf5acc1.jpg: 800x800 1 Color LD, 2 HMs, 7 LD2s, 4 MLPs, 1 Milk Packets, 2 PPs, 12.5ms
# image 15/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_154650_jpg.rf.bdf163f4d10d16dfab581b1d4fa45226.jpg: 800x800 1 Color LD, 1 HM, 1 LD1, 2 LD2s, 2 MLPs, 2 Milk Packetss, 4 PPs, 1 Raffia, 12.4ms
# image 16/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_154921_jpg.rf.8111f03593dc6573aaef548d77de3651.jpg: 800x800 2 HMs, 2 LD2s, 4 MLPs, 1 Milk Packets, 1 PP, 1 Raffia, 12.4ms
# image 17/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_154925_jpg.rf.2e4ad090cc344df7e78d6987048a2119.jpg: 800x800 2 HMs, 2 LD2s, 3 MLPs, 2 Milk Packetss, 1 PP, 1 Raffia, 12.4ms
# image 18/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_155457_jpg.rf.62ebf487076665be6e296c6023d87441.jpg: 800x800 2 Color LDs, 4 LD2s, 3 MLPs, 3 Milk Packetss, 1 PP, 1 Raffia, 12.4ms
# image 19/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_155509_jpg.rf.30444313f571122173a803c84c6f5673.jpg: 800x800 2 Color LDs, 5 LD2s, 3 MLPs, 3 Milk Packetss, 1 PP, 1 Raffia, 12.3ms
# image 20/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241218_155754_jpg.rf.04679123a75a90cb95c2c05eb80c5a7c.jpg: 800x800 1 Color LD, 1 LD1, 4 LD2s, 5 MLPs, 3 Milk Packetss, 4 PPs, 1 Raffia, 12.4ms
# image 21/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241220_131928_jpg.rf.3246e932a92e8054c08cabc1d57d70ae.jpg: 800x800 1 Color LD, 5 HMs, 1 LD2, 1 MLP, 3 PPs, 12.7ms
# image 22/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241220_132034-0-_jpg.rf.e54019e987725cf9216e4ff73b16e003.jpg: 800x800 2 Color LDs, 2 HMs, 1 LD2, 5 PPs, 12.1ms
# image 23/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241220_132202_jpg.rf.78d59a4309ab30695e36ed9bbad8020b.jpg: 800x800 2 Color LDs, 4 HMs, 5 LD2s, 1 MLP, 3 PPs, 11.3ms
# image 24/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241220_132211_jpg.rf.638dba8d7ac5303b0a8613e181368115.jpg: 800x800 3 Color LDs, 6 HMs, 2 LD2s, 3 PPs, 11.2ms
# image 25/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241220_132501_jpg.rf.cbe9d41f5397400856b4097e13bef6b7.jpg: 800x800 5 Color LDs, 2 HMs, 1 LD2, 2 Milk Packetss, 1 PP, 11.7ms
# image 26/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241220_133811_jpg.rf.db7714180066a2bbc54bcde06efb1e65.jpg: 800x800 2 Color LDs, 1 HM, 3 LD2s, 5 MLPs, 2 Milk Packetss, 12.6ms
# image 27/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241220_134657-0-_jpg.rf.2b7b07c0657ced7d61665a4e0e762a76.jpg: 800x800 1 Color LD, 1 HM, 4 LD2s, 7 MLPs, 2 Milk Packetss, 2 PPs, 12.3ms
# image 28/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241220_140412_jpg.rf.ce3036e1ec91f49ebd5fb2f61e65946f.jpg: 800x800 2 Color LDs, 3 HMs, 3 LD2s, 2 MLPs, 2 Milk Packetss, 3 PPs, 11.3ms
# image 29/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241220_153527_jpg.rf.505d5f4f9fde22be18cbcaf26bbfb804.jpg: 800x800 1 Color LD, 4 HMs, 3 LD2s, 1 MLP, 4 Milk Packetss, 3 PPs, 11.2ms
# image 30/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241220_154027_jpg.rf.29a2ae2b59cb716ce1260f86808adefa.jpg: 800x800 1 Color LD, 4 HMs, 1 LD2, 5 MLPs, 2 Milk Packetss, 1 PP, 12.0ms
# image 31/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/20241220_154152_jpg.rf.5b77cbffa610444ac0bf661e032f0fdf.jpg: 800x800 4 HMs, 1 LD2, 4 MLPs, 4 Milk Packetss, 1 PP, 12.3ms
# image 32/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/24_jpg.rf.729926dd497c4dce41d0ded460a59599.jpg: 800x800 1 Color LD, 6 HMs, 1 LD2, 11 MLPs, 11.7ms
# image 33/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/25_jpg.rf.d195960c0e535aafdc987e2cedce0c6e.jpg: 800x800 1 Color LD, 6 HMs, 1 LD2, 12 MLPs, 11.2ms
# image 34/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/28_jpg.rf.e6477cc0e24572d9a05cee164600734a.jpg: 800x800 1 Color LD, 6 HMs, 1 LD2, 11 MLPs, 11.5ms
# image 35/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/72_jpg.rf.59db072c16617090e1673e71096409a3.jpg: 800x800 1 Color LD, 8 HMs, 1 LD2, 14 MLPs, 12.5ms
# image 36/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/IMG_20241220_152313_jpg.rf.ae854a6d93c37bf6d0dc4da2b131880d.jpg: 800x800 2 HMs, 2 LD2s, 5 MLPs, 2 Milk Packetss, 3 PPs, 11.9ms
# image 37/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/IMG_20241220_152323_jpg.rf.3660e3a98962b6289ebef4f46530d325.jpg: 800x800 1 Color LD, 1 HM, 3 LD2s, 5 MLPs, 3 Milk Packetss, 3 PPs, 11.2ms
# image 38/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/IMG_20241220_152806_jpg.rf.b12a2cbef94a36736c604f3d07a65972.jpg: 800x800 1 Color LD, 1 HM, 2 LD2s, 2 MLPs, 3 Milk Packetss, 6 PPs, 1 Raffia, 11.4ms
# image 39/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/IMG_20241220_152911_jpg.rf.1f96efeb0c3273ca125f614a4c7fb713.jpg: 800x800 1 HM, 1 LD1, 2 LD2s, 2 MLPs, 2 Milk Packetss, 5 PPs, 1 Raffia, 12.1ms
# image 40/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_11_2024-12-23_09-21-33_jpg.rf.6fb4572c1f6da98b676185e2033d37ff.jpg: 800x800 2 Color LDs, 4 HMs, 1 LD1, 4 LD2s, 3 MLPs, 3 Milk Packetss, 5 PPs, 12.3ms
# image 41/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_19_2024-12-23_09-25-36_jpg.rf.77b3403b12e87426e7b568e6b99eea18.jpg: 800x800 2 Color LDs, 6 HMs, 2 LD2s, 3 Milk Packetss, 2 PPs, 11.4ms
# image 42/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_19_2024-12-28_16-41-21-2-_jpg.rf.3134808428c95f7bdd6e027c8a2c09ec.jpg: 800x800 2 Color LDs, 4 HMs, 1 LD1, 3 LD2s, 3 MLPs, 1 Milk Packets, 3 PPs, 11.3ms
# image 43/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_1_2024-12-23_09-24-57_jpg.rf.6a403d6238f1ab2636984e46036ab14c.jpg: 800x800 1 Color LD, 6 HMs, 1 LD1, 4 LD2s, 2 Milk Packetss, 3 PPs, 11.9ms
# image 44/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_21_2024-12-28_16-40-24-2-_jpg.rf.142010d95246e3fee2fb94b439bac8f5.jpg: 800x800 4 HMs, 1 LD1, 3 LD2s, 4 MLPs, 2 Milk Packetss, 3 PPs, 12.1ms
# image 45/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_22_2024-12-28_16-42-32-3-_jpg.rf.f9a3388bda9640398f8c9509b8a39f56.jpg: 800x800 1 Color LD, 5 HMs, 2 LD2s, 2 MLPs, 3 Milk Packetss, 3 PPs, 1 Raffia, 11.3ms
# image 46/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_24_2024-12-23_09-24-57_jpg.rf.6498d2bd1d9d528662fbe8f8e194156a.jpg: 800x800 9 HMs, 3 LD2s, 1 MLP, 2 Milk Packetss, 4 PPs, 1 Raffia, 11.2ms
# image 47/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_24_2024-12-28_16-41-21_jpg.rf.17cca8eefae548510439bf7d2764f158.jpg: 800x800 5 HMs, 1 LD1, 3 LD2s, 2 MLPs, 2 Milk Packetss, 2 PPs, 11.8ms
# image 48/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_29_2024-12-28_16-41-21-4-_jpg.rf.1da7fe8076bac0ace05db5e9d7c7a14a.jpg: 800x800 5 HMs, 1 LD1, 3 LD2s, 2 MLPs, 2 Milk Packetss, 2 PPs, 12.3ms
# image 49/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_30_2024-12-28_16-39-20-4-_jpg.rf.08e8e29ea9a22ac617435e07129926e4.jpg: 800x800 1 HM, 3 LD2s, 6 MLPs, 3 Milk Packetss, 3 PPs, 11.4ms
# image 50/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_31_2024-12-28_16-43-07-3-_jpg.rf.15b424fd00f8c093652062222123b9cc.jpg: 800x800 1 Color LD, 4 HMs, 1 LD2, 1 MLP, 1 Milk Packets, 2 PPs, 12.0ms
# image 51/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_37_2024-12-23_09-25-17_jpg.rf.f8823de080cb8bfa8cce57f7eb2ebbd5.jpg: 800x800 1 Color LD, 5 HMs, 1 LD1, 3 Milk Packetss, 6 PPs, 12.2ms
# image 52/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_37_2024-12-23_09-25-36_jpg.rf.5b28abba602dae35f79f8238a26a5a8a.jpg: 800x800 2 Color LDs, 3 HMs, 4 LD2s, 1 MLP, 3 Milk Packetss, 1 PP, 11.5ms
# image 53/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_38_2024-12-23_09-21-33_jpg.rf.645890662e329f70b9df993420649ec2.jpg: 800x800 1 Color LD, 5 HMs, 5 LD2s, 4 MLPs, 3 Milk Packetss, 4 PPs, 11.2ms
# image 54/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_38_2024-12-28_16-38-28_jpg.rf.7d730dbd3f5b4934381fab4770f12e01.jpg: 800x800 2 HMs, 3 LD2s, 7 MLPs, 2 Milk Packetss, 3 PPs, 1 Raffia, 11.6ms
# image 55/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_41_2024-12-28_16-42-32_jpg.rf.bb75880e4f2446d2161a196dd7f1ffa0.jpg: 800x800 3 Color LDs, 5 HMs, 1 LD2, 1 MLP, 3 Milk Packetss, 3 PPs, 1 Raffia, 12.5ms
# image 56/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_46_2024-12-28_16-41-21-1-_jpg.rf.35641a707ed75b91986e968abdf39737.jpg: 800x800 3 Color LDs, 4 HMs, 1 LD1, 3 LD2s, 2 MLPs, 2 Milk Packetss, 4 PPs, 1 Raffia, 11.7ms
# image 57/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_47_2024-12-28_16-38-28-1-_jpg.rf.5613ed3124c5171f6810f38489791bdc.jpg: 800x800 3 HMs, 1 LD2, 6 MLPs, 3 Milk Packetss, 4 PPs, 11.3ms
# image 58/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_48_2024-12-28_16-39-20-2-_jpg.rf.2cddc00e37cb00fd134d36bd057cee6f.jpg: 800x800 2 Color LDs, 4 HMs, 1 LD1, 2 LD2s, 5 MLPs, 2 Milk Packetss, 2 PPs, 11.9ms
# image 59/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_54_2024-12-28_16-40-24_jpg.rf.151b37c7217e1489364a5121f87cd3f2.jpg: 800x800 3 HMs, 1 LD1, 3 LD2s, 6 MLPs, 1 Milk Packets, 1 PP, 12.1ms
# image 60/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_61_2024-12-28_16-43-07_jpg.rf.2fa3b3df2c8ff9474ba4b5ffe84daef9.jpg: 800x800 3 Color LDs, 2 HMs, 3 LD2s, 1 MLP, 3 Milk Packetss, 2 PPs, 11.4ms
# image 61/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_67_2024-12-28_16-38-28_jpg.rf.1385bdf7993489752f4e1c116ef603d1.jpg: 800x800 4 HMs, 2 LD2s, 7 MLPs, 2 Milk Packetss, 1 PP, 11.2ms
# image 62/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_67_2024-12-28_16-42-32_jpg.rf.feea5fea443c7566f79e00fc92be7c77.jpg: 800x800 5 Color LDs, 4 HMs, 3 LD2s, 2 MLPs, 2 Milk Packetss, 1 PP, 1 Raffia, 11.6ms
# image 63/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_6_2024-12-23_09-24-57_jpg.rf.93ee9838210a7c7a5772639e2c37e9d7.jpg: 800x800 1 Color LD, 6 HMs, 3 LD2s, 2 Milk Packetss, 4 PPs, 12.5ms
# image 64/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_70_2024-12-28_16-40-24_jpg.rf.f5b672c92cca6c04f8653bed1c76feeb.jpg: 800x800 1 Color LD, 4 HMs, 1 LD1, 2 LD2s, 6 MLPs, 2 Milk Packetss, 1 PP, 11.8ms
# image 65/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_73_2024-12-28_16-38-28_jpg.rf.583be65fc03ea532fb73c7e44bb579b5.jpg: 800x800 2 HMs, 3 LD2s, 6 MLPs, 2 Milk Packetss, 3 PPs, 11.3ms
# image 66/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_78_2024-12-28_16-38-28_jpg.rf.c879e93a5f8cd2d0e760f6163751e115.jpg: 800x800 2 HMs, 3 LD2s, 6 MLPs, 2 Milk Packetss, 3 PPs, 11.7ms
# image 67/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_78_2024-12-28_16-41-21_jpg.rf.84db7a06ac39dc79257f195dc992096f.jpg: 800x800 3 Color LDs, 5 HMs, 3 LD2s, 3 MLPs, 2 Milk Packetss, 2 PPs, 12.3ms
# image 68/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_84_2024-12-28_16-38-28_jpg.rf.ab38bd9c86533c53ead5cfcbda8d3c22.jpg: 800x800 3 HMs, 3 LD2s, 8 MLPs, 3 Milk Packetss, 3 PPs, 11.4ms
# image 69/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_86_2024-12-28_16-39-20_jpg.rf.bc40e507f432b8f4fdfe07cc018457d0.jpg: 800x800 3 Color LDs, 3 HMs, 1 LD1, 2 LD2s, 5 MLPs, 2 Milk Packetss, 2 PPs, 11.3ms
# image 70/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_86_2024-12-28_16-42-32_jpg.rf.9e59f38af732d7956af6269b86895032.jpg: 800x800 4 Color LDs, 5 HMs, 3 LD2s, 2 MLPs, 1 Milk Packets, 2 PPs, 12.0ms
# image 71/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_89_2024-12-28_16-41-21_jpg.rf.25678e94bf9dad70e2778b75dd205973.jpg: 800x800 6 Color LDs, 4 HMs, 1 LD2, 2 MLPs, 2 Milk Packetss, 3 PPs, 1 Raffia, 12.0ms
# image 72/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_92_2024-12-28_16-40-24_jpg.rf.d93bf585bb05d411284f849d48075754.jpg: 800x800 1 Color LD, 4 HMs, 1 LD1, 3 LD2s, 4 MLPs, 2 Milk Packetss, 1 Raffia, 11.2ms
# image 73/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_94_2024-12-28_16-39-20_jpg.rf.40fd3aa3023e64b3f9e5c1d3adf2bf11.jpg: 800x800 3 Color LDs, 3 HMs, 1 LD1, 2 LD2s, 5 MLPs, 2 Milk Packetss, 2 PPs, 11.4ms
# image 74/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_96_2024-12-28_16-42-32_jpg.rf.d1252aaa6f8cc200c0bf1d73fcf0f537.jpg: 800x800 5 Color LDs, 5 HMs, 1 LD2, 3 MLPs, 3 Milk Packetss, 2 PPs, 1 Raffia, 12.5ms
# image 75/75 /content/{HOME}/datasets/{HOME}/datasets/datasets/My-First-Project-1/test/images/photo_98_2024-12-28_16-41-21_jpg.rf.0506d151202140d1fe9cd3e5263b045f.jpg: 800x800 6 Color LDs, 4 HMs, 1 LD2, 3 MLPs, 2 Milk Packetss, 2 PPs, 1 Raffia, 11.9ms
# Speed: 3.8ms preprocess, 13.1ms inference, 2.1ms postprocess per image at shape (1, 3, 800, 800)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = '/content/runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-4201139547.py in <cell line: 0>()
#       6
#       7 # List all directories that start with 'predict' in the base path
# ----> 8 subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
#       9               if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]
#      10
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/runs/detect/'

# %%
from google.colab import files
files.download(f'{HOME}/runs/detect/train/weights/best.pt')

# %%
# !zip -r yolov8_training_results.zip {HOME}/runs/detect/train/
# Out:
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/ (stored 0%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/weights/ (stored 0%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/weights/best.pt (deflated 8%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/weights/last.pt (deflated 8%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/confusion_matrix.png (deflated 23%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/results.png (deflated 7%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/args.yaml (deflated 52%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/val_batch1_pred.jpg (deflated 4%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/val_batch2_pred.jpg (deflated 3%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/train_batch6280.jpg (deflated 4%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/train_batch2.jpg (deflated 2%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/results.csv (deflated 85%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/train_batch6282.jpg (deflated 5%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/R_curve.png (deflated 9%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/train_batch6281.jpg (deflated 3%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/F1_curve.png (deflated 8%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/val_batch1_labels.jpg (deflated 4%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/labels_correlogram.jpg (deflated 34%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/P_curve.png (deflated 9%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/confusion_matrix_normalized.png (deflated 20%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/val_batch2_labels.jpg (deflated 4%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/val_batch0_labels.jpg (deflated 4%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/train_batch1.jpg (deflated 2%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/labels.jpg (deflated 27%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/PR_curve.png (deflated 12%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/events.out.tfevents.1757838223.902e18783aed.1971.0 (deflated 90%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/train_batch0.jpg (deflated 1%)
#   adding: content/{HOME}/datasets/{HOME}/datasets/runs/detect/train/val_batch0_pred.jpg (deflated 3%)

# %%
from google.colab import files
files.download("yolov8_training_results.zip")

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv8 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv8 weights.
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.2.103, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/model-examples/football-players-obj-detection/2
# Share your model with the world at: https://universe.roboflow.com/model-examples/football-players-obj-detection/model/2

# %% [markdown]
# Follow the links above to check if the upload succeeded. It may take a couple of minutes until the model is visible to the `roboflow` SDK.

# %%
# Run inference on your model on a persistent, auto-scaling, cloud API

# Load model
model = project.version(dataset.version).model
assert model, "Model deployment is still loading"

# Choose a random test image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
# Out:
# running inference on 4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg
# {'predictions': [{'x': 1227.0,
#    'y': 527.5,
#    'width': 50.0,
#    'height': 77.0,
#    'confidence': 0.9045102000236511,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '7bb0de78-c58d-454a-b693-c3f518f94f80',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 731.0,
#    'y': 584.5,
#    'width': 52.0,
#    'height': 79.0,
#    'confidence': 0.8924632668495178,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'b3ea8a5a-5294-45c9-9221-ba8a6f0884b5',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1397.5,
#    'y': 344.5,
#    'width': 31.0,
#    'height': 55.0,
#    'confidence': 0.8912790417671204,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '5ef87756-163e-442c-ad88-35f3572750d5',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1447.0,
#    'y': 476.5,
#    'width': 32.0,
#    'height': 73.0,
#    'confidence': 0.8694518804550171,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '89a9e4d7-0b7b-4cc0-8596-cf90522a5f86',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1271.0,
#    'y': 583.0,
#    'width': 36.0,
#    'height': 82.0,
#    'confidence': 0.8614903688430786,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '74b59e7e-03a8-477c-bb65-872b55cee6d2',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 332.5,
#    'y': 474.0,
#    'width': 33.0,
#    'height': 72.0,
#    'confidence': 0.8610998392105103,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '50984141-2378-4a7d-8b40-9e353bcf50d9',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 513.5,
#    'y': 379.5,
#    'width': 43.0,
#    'height': 57.0,
#    'confidence': 0.8593119978904724,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '131a232d-1403-498c-8714-ee9bc72768f1',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1050.5,
#    'y': 404.0,
#    'width': 25.0,
#    'height': 66.0,
#    'confidence': 0.8461295962333679,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '17c1060d-60c1-4684-8190-99f32976e3b6',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1524.0,
#    'y': 468.5,
#    'width': 28.0,
#    'height': 75.0,
#    'confidence': 0.8449162244796753,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'b78f434e-4fe3-4d7f-969c-2b540118a036',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 862.0,
#    'y': 299.0,
#    'width': 18.0,
#    'height': 46.0,
#    'confidence': 0.8436365723609924,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'a04d6b50-dfae-4bd3-934a-7c535ae86a6d',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 286.0,
#    'y': 409.0,
#    'width': 28.0,
#    'height': 66.0,
#    'confidence': 0.8423029780387878,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'd4868dd9-213d-4242-b5f4-b0a28bfa5c51',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1113.0,
#    'y': 398.5,
#    'width': 22.0,
#    'height': 65.0,
#    'confidence': 0.8421118855476379,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '808cbedf-7404-41a5-ac38-61a46bfab755',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 867.5,
#    'y': 447.0,
#    'width': 25.0,
#    'height': 70.0,
#    'confidence': 0.8394479155540466,
#    'class': 'referee',
#    'class_id': 3,
#    'detection_id': '3e0537d1-ca58-438c-9323-702e21ddacd2',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 803.0,
#    'y': 461.5,
#    'width': 26.0,
#    'height': 69.0,
#    'confidence': 0.8217413425445557,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'bbdcdcff-9007-4311-96e3-e8a5079f177e',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 832.5,
#    'y': 475.5,
#    'width': 29.0,
#    'height': 67.0,
#    'confidence': 0.8183465003967285,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '9ff9c162-4288-42c4-a90c-c67983551391',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 593.5,
#    'y': 386.5,
#    'width': 25.0,
#    'height': 57.0,
#    'confidence': 0.7829996943473816,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '0898f653-a519-4c0d-abf4-c2f07c38be51',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 647.0,
#    'y': 421.0,
#    'width': 36.0,
#    'height': 64.0,
#    'confidence': 0.771634578704834,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '599da973-e6b5-4d13-b990-480f7a58b083',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 737.0,
#    'y': 239.5,
#    'width': 24.0,
#    'height': 35.0,
#    'confidence': 0.7465640902519226,
#    'class': 'referee',
#    'class_id': 3,
#    'detection_id': 'ba786450-37a1-46bf-a80a-b28eb7252058',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1552.5,
#    'y': 404.5,
#    'width': 27.0,
#    'height': 67.0,
#    'confidence': 0.6716049909591675,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'fd36f2e9-6911-4d9e-93cd-3bd5b75263d0',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'}],
#  'image': {'width': '1920', 'height': '1080'}}

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_thresh,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv5 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv5. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
